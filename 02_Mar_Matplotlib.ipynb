# %%
# Ans 1 : What is Matplotlib 
"""
Matplotlib is a python library used to create 2D graphs and plots by using python scripts.
It has a module named pyplot which makes things easy for plotting by providing feature to control line styles, font properties, formatting axes etc.
It supports a very wide variety of graphs and plots namely :

The plot() function is used to draw points (markers) in a diagram.

import matplotlib.pyplot as plt

By default, the plot() function draws a line from point to point.
To plot only the markers, we can use shortcut string notation parameter 'o', which means 'rings'. plt.plot(xpoints, ypoints, 'o')

We can use the keyword argument marker to emphasize each point with a specified marker plt.plot(ypoints, marker = '*')


WE can use the keyword argument linestyle, or shorter ls, to change the style of the plotted line:
plt.plot(ypoints, linestyle = 'dotted')
plt.plot(ypoints, linestyle = 'dashed')
plt.plot(ypoints,linestyle = 'dashed' , color = 'r', linewidth = '20.5')

for a two line graph
plt.plot(y1)
plt.plot(y2)
plt.show()


Display Multiple Plots:
plt.subplot(1, 2, 1) - 1st sub plot
plt.plot(x,y)
plt.subplot(1, 2, 2) - 2nd subplot
plt.plot(x,y)
plt.show()

Scatter plot 
------------
The scatter() function plots one dot for each observation. 
It needs two arrays of the same length, one for the values of the x-axis, and one for values on the y-axis:

ex : Creating random arrays with 100 values for x-points, y-points, colors and sizes
import matplotlib.pyplot as plt
import numpy as np
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))

colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')
plt.colorbar()
plt.show()


BAR PLOT 
----------

We can use the bar() function to draw bar graphs
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.bar(x,y)
plt.show()

we use barh for horizontal plot


Histograms plot 
---------------
A histogram is a graph showing frequency distributions.
x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show() 


Pie Chart Plot
--------------
We can use the pie() function to draw pie charts:
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]
mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, startangle = 90, explode = myexplode, shadow = True, colors = mycolors)
plt.legend()
plt.show() 

"""

# %%
# Ans 2 : Scatter Plot 
"""
Scatter plot 
------------
The scatter() function plots one dot for each observation. 
It needs two arrays of the same length, one for the values of the x-axis, and one for values on the y-axis:
"""
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

colors = np.random.randint(100, size=(50))
sizes = 10 * np.random.randint(100, size=(50))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')
plt.xlabel( "Data in X axis")
plt.ylabel ( "Data in y axis")
plt.title("My first Sctter Plot")
plt.colorbar()
plt.show()

# %%
# Ans 3 : 

"""
Subplot is used to Display Multiple Plots:
"""
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0, 1, 2, 3, 4, 5]) 
y1 = np.array([0, 100, 200, 300, 400, 500])

x2 = np.array([0, 1, 2, 3, 4, 5]) 
y2 = np.array([50, 20, 40, 20, 60, 70])

x3 = np.array([0, 1, 2, 3, 4, 5]) 
y3 = np.array([10, 20, 30, 40, 50, 60])

x4 = np.array([0, 1, 2, 3, 4, 5]) 
y4 = np.array([200, 350, 250, 550, 450, 150])

plt.subplot(2, 2, 1)
plt.plot(x1,y1)
plt.title("plt 1")
plt.subplot(2, 2, 2)
plt.plot(x2,y2)
plt.title("plt 2")
plt.subplot(2, 2, 3)
plt.plot(x3,y3)
plt.title("plt 3")
plt.subplot(2, 2, 4)
plt.plot(x4,y4)
plt.title("plt 4")

plt.show()

# %%
# Ans 4 : bar plot
"""
We can use the bar() function to draw bar graphs to vizualize the data  to convey relational information quickly in a visual manner 
"""

import matplotlib.pyplot as plt
import numpy as np

company = np.array(["Apple", "Microsoft", "Google", "AMD"])

profit = np.array([3000, 8000, 1000, 10000])

plt.bar(company,profit)
plt.xlabel("COMPANY")
plt.ylabel("PROFIT")
plt.show()

# %%
# ANS 5 : BOX PLOT   : 

"""
Box Plot is also known as Whisker plot is created to display the summary of the set of data values having properties like minimum, 
first quartile, median, third quartile and maximum. In the box plot, a box is created from the first quartile to the third quartile, 
a vertical line is also there which goes through the box at the median
"""
import matplotlib.pyplot as plt
import numpy as np

box1 = np.random.normal(100, 10, 200)

box2 = np.random.normal(90, 20, 200)

data = [box1, box2]
fig = plt.figure()
ax = fig.add_axes(rect= (1,1,1,1))

bp = ax.boxplot(data)
plt.show()
